# %%
import os
from pathlib import Path
import re
import mne
import pyxdf
fname = Path.cwd()
print(fname)
# Out:
# /Users/badralmahouri/Documents/project/npulse/software/notebooks

# %%
p = Path.cwd()
repo_root = None
while True:
    if (p / "data").exists() and (p / "notebooks").exists():
        repo_root = p
        break
    if p == p.parent:
        raise FileNotFoundError("Could not find project root containing 'data' and 'notebooks'")
    p = p.parent
data_path = repo_root / "data" / "raw" / "sub-P005" / "emg"

# %%
print(data_path)
# Out:
# /Users/badralmahouri/Documents/project/npulse/software/data/raw/sub-P005/emg

# %%
def find_bids_emg_files(bids_root, subject, session=None, task=None, run=None):
    """
    Return list of (xdf_path, events_path, json_path) for one subject/session/task.
    """
    subj_dir = os.path.join(bids_root, "data")
    subj_dir = os.path.join(subj_dir, "raw")
    subj_dir = os.path.join(subj_dir, f"sub-{subject}")
    if session:
        subj_dir = os.path.join(subj_dir, f"ses-{session}")
    #if task:
    #    subj_dir = os.path.join(subj_dir, f"task-{task}")
    #if run:
    #    subj_dir = os.path.join(subj_dir, f"run-{run}")
    emg_dir = os.path.join(subj_dir, "emg")
    #print(emg_dir)
    if not os.path.exists(emg_dir):
        raise FileNotFoundError(f"No EMG folder for subject {subject}, session {session}")

    pattern = f"sub-{subject}"
    if session:
        pattern += f"_ses-{session}"
    if task:
        pattern += f"_task-{task}"
    if run:
        pattern += f"_run-{run}"
    pattern += "_eeg_up.xdf"
    
    files = [f for f in os.listdir(emg_dir) if re.match(pattern, f)]
    return [os.path.join(emg_dir, f) for f in files]

# %%
find_bids_emg_files(repo_root, subject="P005", session="S002", task="Default", run="001")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 find_bids_emg_files(repo_root, subject="P005", session="S002", task="Default", run="001")
#
# Cell In[7], line 17, in find_bids_emg_files(bids_root, subject, session, task, run)
#      15 #print(emg_dir)
#      16 if not os.path.exists(emg_dir):
# ---> 17     raise FileNotFoundError(f"No EMG folder for subject {subject}, session {session}")
#      19 pattern = f"sub-{subject}"
#      20 if session:
#
# FileNotFoundError: No EMG folder for subject P005, session S002

# %%
def load_emg_bids(bids_root, subject, session=None, task=None, run=None, label_column="event_label"):
    """
    Load EMG data and labels from a BIDS-compliant directory.
    Returns: X (samples x channels), y (labels)
    """
    xdf_files = find_bids_emg_files(bids_root, subject, session, task, run)
    if len(xdf_files) == 0:
        raise FileNotFoundError(f"No EMG EDF found for task={task}")

    xdf_path = xdf_files[0]  # assuming one run
    base_prefix = xdf_path.replace("_emg.xdf", "")
    events_path = base_prefix + "_events.tsv"

    # --- Load EMG signal ---
    """ raw = mne.io.read_raw_edf(xdf_path, preload=True)
    emg_data = raw.get_data().T  # shape: (n_samples, n_channels)
    sfreq = raw.info["sfreq"] """
    streams, header = pyxdf.load_xdf(xdf_path)
    """ data = streams[0]["time_series"].T
    sfreq = float(streams[0]["info"]["nominal_srate"][0])
    info = mne.create_info(3, sfreq, ["eeg", "eeg", "stim"])
    raw = mne.io.RawArray(data, info)
    raw.plot(scalings=dict(eeg=100e-6), duration=1, start=14) """

    # --- Load events ---
    #events_df = pd.read_csv(events_path, sep="\t")

    #if label_column not in events_df.columns:
    #    raise ValueError(f"Missing {label_column} in events.tsv")

    # Align EMG and events (simple approach: expand labels per time window)
    #y = events_df[label_column].to_numpy()
    y=None
    return streams, header

# %%
streams, header = load_emg_bids(repo_root, subject="P005", session="S002", task="Default", run="001")
# Out:
# c:\Users\miski\Desktop\Neuro-X\N-Pulse\npulse-software\data\raw\sub-P005\ses-S002\emg

# %%
streams[1]
# Out:
# {'info': defaultdict(list,
#              {'name': ['eegoSports 000650'],
#               'type': ['EEG'],
#               'channel_count': ['71'],
#               'nominal_srate': ['1000'],
#               'channel_format': ['double64'],
#               'source_id': ['eegoSports_000650'],
#               'version': ['1.1000000000000001'],
#               'created_at': ['7255.1273566999998'],
#               'uid': ['055d0277-59f2-42de-8f97-174699be8396'],
#               'session_id': ['default'],
#               'hostname': ['L-1010036864'],
#               'v4address': [None],
#               'v4data_port': ['16572'],
#               'v4service_port': ['16578'],
#               'v6address': [None],
#               'v6data_port': ['16572'],
#               'v6service_port': ['16578'],
#               'desc': [defaultdict(list,
#                            {'channels': [defaultdict(list,
#                                          {'channel': [defaultdict(list,
#                                                        {'label': ['FP1'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FPZ'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FP2'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['F7'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['F3'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FZ'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['F4'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['F8'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FC5'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FC1'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FC2'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FC6'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['M1'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['T7'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['C3'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['CZ'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['C4'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['T8'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['M2'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['CP5'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['CP1'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['CP2'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['CP6'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['P7'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['P3'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['PZ'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['P4'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['P8'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['POZ'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['O1'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['O2'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['EOG'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['AF7'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['AF3'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['AF4'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['AF8'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['F5'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['F1'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['F2'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['F6'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FC3'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FCZ'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FC4'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['C5'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['C1'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['C2'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['C6'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['CP3'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['CP4'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['P5'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['P1'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['P2'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['P6'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['PO5'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['PO3'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['PO4'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['PO6'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FT7'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['FT8'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['TP7'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['TP8'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['PO7'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['PO8'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['OZ'],
#                                                         'type': ['EEG'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['AUX7'],
#                                                         'type': ['AUX'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['AUX8'],
#                                                         'type': ['AUX'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['AUX9'],
#                                                         'type': ['AUX'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['AUX10'],
#                                                         'type': ['AUX'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['AUX11'],
#                                                         'type': ['AUX'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['AUX12'],
#                                                         'type': ['AUX'],
#                                                         'unit': ['uV']}),
#                                            defaultdict(list,
#                                                        {'label': ['TRIGGER'],
#                                                         'type': ['Markers'],
#                                                         'unit': ['[]']})]})],
#                             'acquisition': [defaultdict(list,
#                                          {'manufacturer': ['antneuro'],
#                                           'serial_number': ['000650']})]})],
#               'stream_id': 2,
#               'effective_srate': np.float64(1000.0018766961758),
#               'segments': [(np.int64(0), np.int64(1794017))]}),
#  'footer': {'info': defaultdict(list,
#               {'first_timestamp': ['7416.651511999999'],
#                'last_timestamp': ['9210.676355000001'],
#                'sample_count': ['1794017'],
#                'clock_offsets': [defaultdict(list,
#                             {'offset': [defaultdict(list,
#                                           {'time': ['7422.319654499999'],
#                                            'value': ['2727.6388372']}),
#                               defaultdict(list,
#                                           {'time': ['7427.319927850001'],
#                                            'value': ['2727.63901125']}),
#                               defaultdict(list,
#                                           {'time': ['7432.320475500001'],
#                                            'value': ['2727.6387308']}),
#                               defaultdict(list,
#                                           {'time': ['7437.320550249999'],
#                                            'value': ['2727.638852550001']}),
#                               defaultdict(list,
#                                           {'time': ['7442.3210397'],
#                                            'value': ['2727.638744300001']}),
#                               defaultdict(list,
#                                           {'time': ['7447.321537399999'],
#                                            'value': ['2727.6384421']}),
#                               defaultdict(list,
#                                           {'time': ['7452.321654400001'],
#                                            'value': ['2727.6386907']}),
#                               defaultdict(list,
#                                           {'time': ['7457.321902400001'],
#                                            'value': ['2727.6386114']}),
#                               defaultdict(list,
#                                           {'time': ['7462.3222741'],
#                                            'value': ['2727.6387575']}),
#                               defaultdict(list,
#                                           {'time': ['7467.322610599999'],
#                                            'value': ['2727.6386013']}),
#                               defaultdict(list,
#                                           {'time': ['7472.32365765'],
#                                            'value': ['2727.63855955']}),
#                               defaultdict(list,
#                                           {'time': ['7477.324003150001'],
#                                            'value': ['2727.63837205']}),
#                               defaultdict(list,
#                                           {'time': ['7482.32385065'],
#                                            'value': ['2727.63876485']}),
#                               defaultdict(list,
#                                           {'time': ['7487.3245215'],
#                                            'value': ['2727.6383447']}),
#                               defaultdict(list,
#                                           {'time': ['7492.3245504'],
#                                            'value': ['2727.638510199999']}),
#                               defaultdict(list,
#                                           {'time': ['7497.325396349999'],
#                                            'value': ['2727.63851595']}),
#                               defaultdict(list,
#                                           {'time': ['7502.325547949999'],
#                                            'value': ['2727.63856135']}),
#                               defaultdict(list,
#                                           {'time': ['7507.325807499999'],
#                                            'value': ['2727.6385764']}),
#                               defaultdict(list,
#                                           {'time': ['7512.326272549999'],
#                                            'value': ['2727.63836445']}),
#                               defaultdict(list,
#                                           {'time': ['7517.326508449999'],
#                                            'value': ['2727.638421250001']}),
#                               defaultdict(list,
#                                           {'time': ['7522.3269447'],
#                                            'value': ['2727.6383933']}),
#                               defaultdict(list,
#                                           {'time': ['7527.327034249999'],
#                                            'value': ['2727.63855355']}),
#                               defaultdict(list,
#                                           {'time': ['7532.32750385'],
#                                            'value': ['2727.63836335']}),
#                               defaultdict(list,
#                                           {'time': ['7537.327707'],
#                                            'value': ['2727.6382461']}),
#                               defaultdict(list,
#                                           {'time': ['7542.3280834'],
#                                            'value': ['2727.6382767']}),
#                               defaultdict(list,
#                                           {'time': ['7547.328308450001'],
#                                            'value': ['2727.63810865']}),
#                               defaultdict(list,
#                                           {'time': ['7552.3287193'],
#                                            'value': ['2727.6381829']}),
#                               defaultdict(list,
#                                           {'time': ['7557.3293546'],
#                                            'value': ['2727.638439700001']}),
#                               defaultdict(list,
#                                           {'time': ['7562.330094700001'],
#                                            'value': ['2727.6381556']}),
#                               defaultdict(list,
#                                           {'time': ['7567.330542349999'],
#                                            'value': ['2727.63827135']}),
#                               defaultdict(list,
#                                           {'time': ['7572.331416450001'],
#                                            'value': ['2727.63810025']}),
#                               defaultdict(list,
#                                           {'time': ['7577.3318249'],
#                                            'value': ['2727.6380899']}),
#                               defaultdict(list,
#                                           {'time': ['7582.332400349999'],
#                                            'value': ['2727.638179750001']}),
#                               defaultdict(list,
#                                           {'time': ['7587.332689999999'],
#                                            'value': ['2727.6380623']}),
#                               defaultdict(list,
#                                           {'time': ['7592.333312349999'],
#                                            'value': ['2727.637991250001']}),
#                               defaultdict(list,
#                                           {'time': ['7597.333607600001'],
#                                            'value': ['2727.6379783']}),
#                               defaultdict(list,
#                                           {'time': ['7602.333880050001'],
#                                            'value': ['2727.63804555']}),
#                               defaultdict(list,
#                                           {'time': ['7607.33486455'],
#                                            'value': ['2727.63795485']}),
#                               defaultdict(list,
#                                           {'time': ['7612.335800549999'],
#                                            'value': ['2727.637946849999']}),
#                               defaultdict(list,
#                                           {'time': ['7617.336063799999'],
#                                            'value': ['2727.6379006']}),
#                               defaultdict(list,
#                                           {'time': ['7622.33639065'],
#                                            'value': ['2727.63776525']}),
#                               defaultdict(list,
#                                           {'time': ['7627.33728845'],
#                                            'value': ['2727.63785135']}),
#                               defaultdict(list,
#                                           {'time': ['7632.337514249999'],
#                                            'value': ['2727.63782695']}),
#                               defaultdict(list,
#                                           {'time': ['7637.337967649999'],
#                                            'value': ['2727.63762725']}),
#                               defaultdict(list,
#                                           {'time': ['7642.3380211'],
#                                            'value': ['2727.6377486']}),
#                               defaultdict(list,
#                                           {'time': ['7647.338116450001'],
#                                            'value': ['2727.637850649999']}),
#                               defaultdict(list,
#                                           {'time': ['7652.33897905'],
#                                            'value': ['2727.63773675']}),
#                               defaultdict(list,
#                                           {'time': ['7657.339087'],
#                                            'value': ['2727.637707599999']}),
#                               defaultdict(list,
#                                           {'time': ['7662.3393383'],
#                                            'value': ['2727.6376979']}),
#                               defaultdict(list,
#                                           {'time': ['7667.3395893'],
#                                            'value': ['2727.637739499999']}),
#                               defaultdict(list,
#                                           {'time': ['7672.339958800001'],
#                                            'value': ['2727.637652']}),
#                               defaultdict(list,
#                                           {'time': ['7677.341043199999'],
#                                            'value': ['2727.6375894']}),
#                               defaultdict(list,
#                                           {'time': ['7682.34124005'],
#                                            'value': ['2727.637556449999']}),
#                               defaultdict(list,
#                                           {'time': ['7687.341455100001'],
#                                            'value': ['2727.6375274']}),
#                               defaultdict(list,
#                                           {'time': ['7692.341538999999'],
#                                            'value': ['2727.637587000001']}),
#                               defaultdict(list,
#                                           {'time': ['7697.342593699999'],
#                                            'value': ['2727.6375346']}),
#                               defaultdict(list,
#                                           {'time': ['7702.342904899999'],
#                                            'value': ['2727.6375313']}),
#                               defaultdict(list,
#                                           {'time': ['7707.343662199999'],
#                                            'value': ['2727.6375059']}),
#                               defaultdict(list,
#                                           {'time': ['7712.34392465'],
#                                            'value': ['2727.637485549999']}),
#                               defaultdict(list,
#                                           {'time': ['7717.344782099999'],
#                                            'value': ['2727.637430700001']}),
#                               defaultdict(list,
#                                           {'time': ['7722.34528845'],
#                                            'value': ['2727.63735875']}),
#                               defaultdict(list,
#                                           {'time': ['7727.3454465'],
#                                            'value': ['2727.6373797']}),
#                               defaultdict(list,
#                                           {'time': ['7732.346404100001'],
#                                            'value': ['2727.6372847']}),
#                               defaultdict(list,
#                                           {'time': ['7737.34708655'],
#                                            'value': ['2727.63727745']}),
#                               defaultdict(list,
#                                           {'time': ['7742.34737315'],
#                                            'value': ['2727.63727075']}),
#                               defaultdict(list,
#                                           {'time': ['7747.347598600001'],
#                                            'value': ['2727.637260899999']}),
#                               defaultdict(list,
#                                           {'time': ['7752.34771335'],
#                                            'value': ['2727.637327349999']}),
#                               defaultdict(list,
#                                           {'time': ['7757.347825350001'],
#                                            'value': ['2727.637272049999']}),
#                               defaultdict(list,
#                                           {'time': ['7762.3484001'],
#                                            'value': ['2727.637188']}),
#                               defaultdict(list,
#                                           {'time': ['7767.348613150001'],
#                                            'value': ['2727.63715555']}),
#                               defaultdict(list,
#                                           {'time': ['7772.349416'],
#                                            'value': ['2727.6371864']}),
#                               defaultdict(list,
#                                           {'time': ['7777.34959695'],
#                                            'value': ['2727.63716365']}),
#                               defaultdict(list,
#                                           {'time': ['7782.34984235'],
#                                            'value': ['2727.63716775']}),
#                               defaultdict(list,
#                                           {'time': ['7787.351103600001'],
#                                            'value': ['2727.6369864']}),
#                               defaultdict(list,
#                                           {'time': ['7792.35201825'],
#                                            'value': ['2727.63701875']}),
#                               defaultdict(list,
#                                           {'time': ['7797.353124399999'],
#                                            'value': ['2727.6368911']}),
#                               defaultdict(list,
#                                           {'time': ['7802.35354605'],
#                                            'value': ['2727.63698445']}),
#                               defaultdict(list,
#                                           {'time': ['7807.3541348'],
#                                            'value': ['2727.637']}),
#                               defaultdict(list,
#                                           {'time': ['7812.354293900001'],
#                                            'value': ['2727.6370198']}),
#                               defaultdict(list,
#                                           {'time': ['7817.3546351'],
#                                            'value': ['2727.636942999999']}),
#                               defaultdict(list,
#                                           {'time': ['7822.355736349999'],
#                                            'value': ['2727.63690955']}),
#                               defaultdict(list,
#                                           {'time': ['7827.3558347'],
#                                            'value': ['2727.6369859']}),
#                               defaultdict(list,
#                                           {'time': ['7832.35685785'],
#                                            'value': ['2727.636865349999']}),
#                               defaultdict(list,
#                                           {'time': ['7837.357738899999'],
#                                            'value': ['2727.6368101']}),
#                               defaultdict(list,
#                                           {'time': ['7842.358410499999'],
#                                            'value': ['2727.6368191']}),
#                               defaultdict(list,
#                                           {'time': ['7847.3586271'],
#                                            'value': ['2727.6367971']}),
#                               defaultdict(list,
#                                           {'time': ['7852.36244565'],
#                                            'value': ['2727.63684435']}),
#                               defaultdict(list,
#                                           {'time': ['7857.362989649999'],
#                                            'value': ['2727.63672335']}),
#                               defaultdict(list,
#                                           {'time': ['7862.3629'],
#                                            'value': ['2727.6376697']}),
#                               defaultdict(list,
#                                           {'time': ['7867.364099699999'],
#                                            'value': ['2727.6367065']}),
#                               defaultdict(list,
#                                           {'time': ['7872.36452395'],
#                                            'value': ['2727.63659725']}),
#                               defaultdict(list,
#                                           {'time': ['7877.365578249999'],
#                                            'value': ['2727.63660515']}),
#                               defaultdict(list,
#                                           {'time': ['7882.366714400001'],
#                                            'value': ['2727.636592799999']}),
#                               defaultdict(list,
#                                           {'time': ['7887.3674997'],
#                                            'value': ['2727.636702899999']}),
#                               defaultdict(list,
#                                           {'time': ['7892.370614649999'],
#                                            'value': ['2727.63643835']}),
#                               defaultdict(list,
#                                           {'time': ['7897.3710923'],
#                                            'value': ['2727.6366339']}),
#                               defaultdict(list,
#                                           {'time': ['7902.371154500001'],
#                                            'value': ['2727.6367142']}),
#                               defaultdict(list,
#                                           {'time': ['7907.3721811'],
#                                            'value': ['2727.636616400001']}),
#                               defaultdict(list,
#                                           {'time': ['7912.37316885'],
#                                            'value': ['2727.63649025']}),
#                               defaultdict(list,
#                                           {'time': ['7917.373385100002'],
#                                            'value': ['2727.636405199999']}),
#                               defaultdict(list,
#                                           {'time': ['7922.374000950001'],
#                                            'value': ['2727.63611165']}),
#                               defaultdict(list,
#                                           {'time': ['7927.3741187'],
#                                            'value': ['2727.6363721']}),
#                               defaultdict(list,
#                                           {'time': ['7932.3752076'],
#                                            'value': ['2727.636217']}),
#                               defaultdict(list,
#                                           {'time': ['7937.375878700001'],
#                                            'value': ['2727.6365056']}),
#                               defaultdict(list,
#                                           {'time': ['7942.377277700001'],
#                                            'value': ['2727.635973599999']}),
#                               defaultdict(list,
#                                           {'time': ['7947.377404699999'],
#                                            'value': ['2727.6364071']}),
#                               defaultdict(list,
#                                           {'time': ['7952.377851699999'],
#                                            'value': ['2727.6362308']}),
#                               defaultdict(list,
#                                           {'time': ['7957.378606099999'],
#                                            'value': ['2727.6358123']}),
#                               defaultdict(list,
#                                           {'time': ['7962.3784206'],
#                                            'value': ['2727.6361082']}),
#                               defaultdict(list,
#                                           {'time': ['7967.379423150001'],
#                                            'value': ['2727.63527815']}),
#                               defaultdict(list,
#                                           {'time': ['7972.37958655'],
#                                            'value': ['2727.63602175']}),
#                               defaultdict(list,
#                                           {'time': ['7977.379407500001'],
#                                            'value': ['2727.6363222']}),
#                               defaultdict(list,
#                                           {'time': ['7982.380641'],
#                                            'value': ['2727.635519800001']}),
#                               defaultdict(list,
#                                           {'time': ['7987.380386549999'],
#                                            'value': ['2727.63596635']}),
#                               defaultdict(list,
#                                           {'time': ['7992.380568750001'],
#                                            'value': ['2727.63597435']}),
#                               defaultdict(list,
#                                           {'time': ['7997.3807757'],
#                                            'value': ['2727.6360284']}),
#                               defaultdict(list,
#                                           {'time': ['8002.380875999999'],
#                                            'value': ['2727.6362632']}),
#                               defaultdict(list,
#                                           {'time': ['8007.3820278'],
#                                            'value': ['2727.6358229']}),
#                               defaultdict(list,
#                                           {'time': ['8012.383677350001'],
#                                            'value': ['2727.63520465']}),
#                               defaultdict(list,
#                                           {'time': ['8017.38333835'],
#                                            'value': ['2727.635906949999']}),
#                               defaultdict(list,
#                                           {'time': ['8022.38407285'],
#                                            'value': ['2727.63577715']}),
#                               defaultdict(list,
#                                           {'time': ['8027.384185999999'],
#                                            'value': ['2727.635737300001']}),
#                               defaultdict(list,
#                                           {'time': ['8032.3844966'],
#                                            'value': ['2727.6357669']}),
#                               defaultdict(list,
#                                           {'time': ['8037.384798399999'],
#                                            'value': ['2727.635768200001']}),
#                               defaultdict(list,
#                                           {'time': ['8042.3857928'],
#                                            'value': ['2727.6356233']}),
#                               defaultdict(list,
#                                           {'time': ['8047.386548600001'],
#                                            'value': ['2727.6358489']}),
#                               defaultdict(list,
#                                           {'time': ['8052.38689695'],
#                                            'value': ['2727.63563005']}),
#                               defaultdict(list,
#                                           {'time': ['8057.38724065'],
#                                            'value': ['2727.63581075']}),
#                               defaultdict(list,
#                                           {'time': ['8062.3886451'],
#                                            'value': ['2727.635578']}),
#                               defaultdict(list,
#                                           {'time': ['8067.389513300001'],
#                                            'value': ['2727.6355567']}),
#                               defaultdict(list,
#                                           {'time': ['8072.3900376'],
#                                            'value': ['2727.635610900001']}),
#                               defaultdict(list,
#                                           {'time': ['8077.390436250002'],
#                                            'value': ['2727.63544155']}),
#                               defaultdict(list,
#                                           {'time': ['8082.39060425'],
#                                            'value': ['2727.63552205']}),
#                               defaultdict(list,
#                                           {'time': ['8087.391464400001'],
#                                            'value': ['2727.6354614']}),
#                               defaultdict(list,
#                                           {'time': ['8092.392329700001'],
#                                            'value': ['2727.6354819']}),
#                               defaultdict(list,
#                                           {'time': ['8097.393210800001'],
#                                            'value': ['2727.6354154']}),
#                               defaultdict(list,
#                                           {'time': ['8102.39355945'],
#                                            'value': ['2727.63536545']}),
# ...
#                               defaultdict(list,
#                                           {'time': ['9182.519149399999'],
#                                            'value': ['2727.629169100001']}),
#                               defaultdict(list,
#                                           {'time': ['9187.519777549998'],
#                                            'value': ['2727.62917345']}),
#                               defaultdict(list,
#                                           {'time': ['9192.520435599999'],
#                                            'value': ['2727.6291517']}),
#                               defaultdict(list,
#                                           {'time': ['9197.520573600001'],
#                                            'value': ['2727.6291277']}),
#                               defaultdict(list,
#                                           {'time': ['9202.520937149999'],
#                                            'value': ['2727.62907145']}),
#                               defaultdict(list,
#                                           {'time': ['9207.521445599999'],
#                                            'value': ['2727.629011']}),
#                               defaultdict(list,
#                                           {'time': ['9212.521710249999'],
#                                            'value': ['2727.62888515']})]})]})},
#  'time_series': array([[-5721.38 , -2973.86 , -7214.01 , ..., -2022.079,  3539.197,
#              0.   ],
#         [-5725.15 , -2970.58 , -7217.56 , ..., -2011.351,  3535.919,
#              0.   ],
#         [-5734.37 , -2970.98 , -7220.18 , ..., -2007.179,  3537.707,
#              0.   ],
#         ...,
#         [-6781.41 , -5175.24 , -7188.12 , ...,   195.637,  4496.522,
#              0.   ],
#         [-6759.44 , -5148.38 , -7151.41 , ...,   182.674,  4497.565,
#              0.   ],
#         [-6720.   , -5106.82 , -7111.17 , ...,   172.84 ,  4501.886,
#              0.   ]], shape=(1794018, 71)),
#  'time_stamps': array([10144.28630628, 10144.28730628, 10144.28830628, ...,
#         11938.29793946, 11938.29893946, 11938.29993946], shape=(1794018,)),
#  'clock_times': [7422.319654499999,
#   7427.3199278500015,
#   7432.320475500001,
#   7437.320550249999,
#   7442.3210397,
#   7447.321537399999,
#   7452.321654400001,
#   7457.321902400001,
#   7462.3222741,
#   7467.322610599999,
#   7472.32365765,
#   7477.324003150001,
#   7482.32385065,
#   7487.3245215,
#   7492.3245504,
#   7497.325396349999,
#   7502.3255479499985,
#   7507.325807499999,
#   7512.326272549999,
#   7517.326508449999,
#   7522.3269447,
#   7527.327034249999,
#   7532.32750385,
#   7537.327707,
#   7542.3280834,
#   7547.328308450001,
#   7552.3287193,
#   7557.3293546,
#   7562.330094700001,
#   7567.330542349999,
#   7572.331416450001,
#   7577.3318249,
#   7582.332400349999,
#   7587.332689999999,
#   7592.333312349999,
#   7597.333607600001,
#   7602.3338800500005,
#   7607.33486455,
#   7612.3358005499995,
#   7617.3360637999995,
#   7622.33639065,
#   7627.33728845,
#   7632.337514249999,
#   7637.337967649999,
#   7642.3380211,
#   7647.338116450001,
#   7652.33897905,
#   7657.339087,
#   7662.3393383,
#   7667.3395893,
#   7672.339958800001,
#   7677.341043199999,
#   7682.34124005,
#   7687.3414551000005,
#   7692.341538999999,
#   2727.6314147499997,
#   2727.63138205,
#   2727.6313895499998,
#   2727.6314790999995,
#   2727.6312672999993,
#   2727.6312503500003,
#   2727.6312703999993,
#   2727.6314174500003,
#   2727.6311568500005,
#   2727.6311951999996,
#   2727.6311131,
#   2727.6311169499995,
#   2727.63110755,
#   2727.6309058000006,
#   2727.631219850001,
#   2727.63101705,
#   2727.63098275,
#   2727.6309674500008,
#   2727.63080625,
#   2727.630921950001,
#   2727.63079545,
#   2727.6308324,
#   2727.63077445,
#   2727.63072665,
#   2727.6307400000005,
#   2727.6307101499997,
#   2727.630724750001,
#   2727.6306248500005,
#   2727.6306443500007,
#   2727.6305725500006,
#   2727.630644,
#   2727.6304996500003,
#   2727.630570550001,
#   2727.6304060500006,
#   2727.6304564,
#   2727.630443350001,
#   2727.6304390000005,
#   2727.630415750001,
#   2727.6303507499997,
#   2727.63035975,
#   2727.6302561500006,
#   2727.6302011,
#   2727.63023245,
#   2727.6301276999993,
#   2727.6301138,
#   2727.6301240500006,
#   2727.6299839999992,
#   2727.6300612999994,
#   2727.6300497,
#   2727.6300119999996,
#   2727.6299486499993,
#   2727.6300922500004,
#   2727.6300517499994,
#   2727.6300518999997,
#   2727.6298660499997,
#   2727.6298331999997,
#   2727.62976685,
#   2727.6298402,
#   2727.6297665499997,
#   2727.62956925,
#   2727.6297572000003,
#   2727.6295634,
#   2727.6295208,
#   2727.629518399999,
#   2727.6295973999995,
#   2727.6295388,
#   2727.6293807499997,
#   2727.6295258499995,
#   2727.6295019500003,
#   2727.629393349999,
#   2727.629410649999,
#   2727.6294885999996,
#   2727.6293221999995,
#   2727.6292058999998,
#   2727.629233650001,
#   2727.6292085999994,
#   2727.629071049999,
#   2727.6291691000015,
#   2727.62917345,
#   2727.6291517,
#   2727.6291277,
#   2727.62907145,
#   2727.629011,
#   2727.6288851500003]}

# %%
streams[0]
# Out:
# {'info': defaultdict(list,
#              {'name': ['stimulus_stream'],
#               'type': ['Markers'],
#               'channel_count': ['1'],
#               'channel_format': ['int32'],
#               'source_id': ['stimulus_stream_001'],
#               'nominal_srate': ['0.000000000000000'],
#               'version': ['1.100000000000000'],
#               'created_at': ['10014.17207990000'],
#               'uid': ['72e7b7f1-2010-4c69-8037-e77479367c40'],
#               'session_id': ['default'],
#               'hostname': ['L-1027100110'],
#               'v4address': [None],
#               'v4data_port': ['16572'],
#               'v4service_port': ['16572'],
#               'v6address': [None],
#               'v6data_port': ['16572'],
#               'v6service_port': ['16572'],
#               'desc': [defaultdict(list,
#                            {'experiment': [defaultdict(list,
#                                          {'task': ['Upper-limb both arms'],
#                                           'version': ['7.2 (event CSV with triggers)']})]})],
#               'stream_id': 1,
#               'effective_srate': 0,
#               'segments': []}),
#  'footer': {'info': defaultdict(list,
#               {'first_timestamp': ['10164.3362356'],
#                'last_timestamp': ['11929.840321'],
#                'sample_count': ['363'],
#                'clock_offsets': [defaultdict(list,
#                             {'offset': [defaultdict(list,
#                                           {'time': ['10149.96243095'],
#                                            'value': ['-3.64500001523993e-05']}),
#                               defaultdict(list,
#                                           {'time': ['10154.96258605'],
#                                            'value': ['-2.694999966479372e-05']}),
#                               defaultdict(list,
#                                           {'time': ['